# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Highest and lowest total score in an inning

# %%
df=pd.read_csv("deliveries.csv")

# %%
inning=df.groupby(["match_id","inning"])["total_runs"].sum().reset_index()

# %%
inning
# Out:
#       match_id  inning  total_runs
# 0            1       1         207
# 1            1       2         172
# 2            2       1         184
# 3            2       2         187
# 4            3       1         183
# ...        ...     ...         ...
# 1279       634       2         140
# 1280       635       1         162
# 1281       635       2         163
# 1282       636       1         208
# 1283       636       2         200
#
# [1284 rows x 3 columns]

# %%
inning["total_runs"].max()
# Out:
# 263

# %%
inning["total_runs"].min()
# Out:
# 2

# %%
#Virat

# %%
kohli_runs = df[df["batsman"] == "V Kohli"]

# %%
kohli_runs
# Out:
#         match_id  inning                 batting_team         bowling_team  \
# 2590          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2591          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2593          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2594          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2597          12       1  Royal Challengers Bangalore       Mumbai Indians
# ...          ...     ...                          ...                  ...
# 150410       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150413       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150414       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150415       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 150416       636       2  Royal Challengers Bangalore  Sunrisers Hyderabad
#
# ...

# %%
kohli_runs.groupby("match_id")["batsman_runs"].sum().mean()
# Out:
# 31.368794326241133

# %%
 #If a team scores above 200 in first innings, what is their probablity of winning

# %%
match=df.groupby(["match_id","inning"])["total_runs"].sum().reset_index()

# %%
match.head()
# Out:
#    match_id  inning  total_runs
# 0         1       1         207
# 1         1       2         172
# 2         2       1         184
# 3         2       2         187
# 4         3       1         183

# %%
inning1=match[match["inning"] == 1]

# %%
inning2=match[match["inning"] == 2]

# %%
inning1.head()
# Out:
#    match_id  inning  total_runs
# 0         1       1         207
# 2         2       1         184
# 4         3       1         183
# 6         4       1         163
# 8         5       1         157

# %%
inning2.head()
# Out:
#    match_id  inning  total_runs
# 1         1       2         172
# 3         2       2         187
# 5         3       2         184
# 7         4       2         164
# 9         5       2         142

# %%
inning1=inning1[inning1["total_runs"]>200]

# %%
inning1.head()
# Out:
#     match_id  inning  total_runs
# 0          1       1         207
# 16         9       1         205
# 38        20       1         213
# 62        32       1         207
# 72        36       1         209

# %%
match_200=pd.merge(inning1,inning2, on = "match_id")

# %%
match_200.head()
# Out:
#    match_id  inning_x  total_runs_x  inning_y  total_runs_y
# 0         1         1           207         2           172
# 1         9         1           205         2           108
# 2        20         1           213         2           192
# 3        32         1           207         2           181
# 4        36         1           209         2           161

# %%
len(match_200)
# Out:
# 47

# %%
win = match_200[match_200["total_runs_x"] > match_200["total_runs_y"]]

# %%
len(win)
# Out:
# 41

# %%
won= won.value_counts()

# %%
won
# Out:
# True     41
# False     6
# dtype: int64
